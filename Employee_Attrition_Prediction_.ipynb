# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/Employee.csv")
df
# Out:
#        Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0             8410   31    Male                19   Education            5390
# 1            64756   59  Female                 4       Media            5534
# 2            30257   24  Female                10  Healthcare            8159
# 3            65791   36  Female                 7   Education            3989
# 4            65026   56    Male                41   Education            4821
# ...            ...  ...     ...               ...         ...             ...
# 74493        16243   56  Female                42  Healthcare            7830
# 74494        47175   30  Female                15   Education            3856
# 74495        12409   52    Male                 5   Education            5654
# 74496         9554   18    Male                 4   Education            5276
# 74497        73042   59  Female                48   Education            3774
#
#       Work-Life Balance Job Satisfaction Performance Rating  \
# 0             Excellent           Medium            Average
# 1                  Poor             High                Low
# 2                  Good             High                Low
# 3                  Good             High               High
# 4                  Fair        Very High            Average
# ...                 ...              ...                ...
# 74493              Poor           Medium            Average
# 74494              Good           Medium            Average
# 74495              Good        Very High      Below Average
# 74496              Fair             High            Average
# 74497              Good             High      Below Average
#
#        Number of Promotions  ... Number of Dependents  Job Level Company Size  \
# 0                       2.0  ...                  0.0        Mid       Medium
# 1                       3.0  ...                  3.0        Mid       Medium
# 2                       0.0  ...                  3.0        Mid       Medium
# 3                       1.0  ...                  2.0        Mid        Small
# 4                       0.0  ...                  0.0     Senior       Medium
# ...                     ...  ...                  ...        ...          ...
# 74493                   0.0  ...                  0.0     Senior       Medium
# 74494                   2.0  ...                  0.0      Entry       Medium
# 74495                   0.0  ...                  4.0        Mid        Small
# 74496                   0.0  ...                  3.0        Mid        Large
# 74497                   1.0  ...                  4.0        Mid        Large
#
#       Company Tenure  Remote Work Leadership Opportunities  \
# 0                 89           No                       No
# 1                 21           No                       No
# 2                 74           No                       No
# 3                 50          Yes                       No
# 4                 68           No                       No
# ...              ...          ...                      ...
# 74493             60           No                       No
# 74494             20           No                       No
# 74495              7           No                       No
# 74496              5           No                       No
# 74497            118           No                       No
#
#       Innovation Opportunities  Company Reputation Employee Recognition  \
# 0                           No           Excellent               Medium
# 1                           No                Fair                  Low
# 2                           No                Poor                  Low
# 3                           No                Good               Medium
# 4                           No                Fair               Medium
# ...                        ...                 ...                  ...
# 74493                       No                Poor               Medium
# 74494                       No                Good               Medium
# 74495                       No                Good                 High
# 74496                       No                Poor                 High
# 74497                       No                Good            Very High
#
#       Attrition
# 0        Stayed
# 1        Stayed
# 2        Stayed
# 3        Stayed
# 4        Stayed
# ...         ...
# 74493    Stayed
# 74494      Left
# 74495      Left
# 74496    Stayed
# 74497      Left
#
# [74498 rows x 24 columns]

# %%
df.head(10)
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
# 5        24368   38  Female                 3  Technology            9977
# 6        64970   47    Male                23   Education            3681
# 7        36999   48    Male                16     Finance           11223
# 8        32714   57    Male                44   Education            3773
# 9        15944   24  Female                 1  Healthcare            7319
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                   2.0
# 1              Poor             High                Low                   3.0
# 2              Good             High                Low                   0.0
# 3              Good             High               High                   1.0
# 4              Fair        Very High            Average                   0.0
# 5              Fair             High      Below Average                   3.0
# 6              Fair             High               High                   1.0
# 7         Excellent        Very High               High                   2.0
# 8              Good           Medium               High                   1.0
# 9              Poor             High            Average                   1.0
#
#    ... Number of Dependents  Job Level Company Size Company Tenure  \
# 0  ...                  0.0        Mid       Medium             89
# 1  ...                  3.0        Mid       Medium             21
# 2  ...                  3.0        Mid       Medium             74
# 3  ...                  2.0        Mid        Small             50
# 4  ...                  0.0     Senior       Medium             68
# 5  ...                  0.0        Mid       Medium             47
# 6  ...                  3.0      Entry        Small             93
# 7  ...                  4.0      Entry       Medium             88
# 8  ...                  4.0      Entry       Medium             75
# 9  ...                  4.0      Entry        Large             45
#
#    Remote Work Leadership Opportunities Innovation Opportunities  \
# 0           No                       No                       No
# 1           No                       No                       No
# 2           No                       No                       No
# 3          Yes                       No                       No
# 4           No                       No                       No
# 5           No                       No                      Yes
# 6           No                       No                       No
# 7           No                       No                       No
# 8           No                       No                       No
# 9           No                       No                      Yes
#
#    Company Reputation Employee Recognition Attrition
# 0           Excellent               Medium    Stayed
# 1                Fair                  Low    Stayed
# 2                Poor                  Low    Stayed
# 3                Good               Medium    Stayed
# 4                Fair               Medium    Stayed
# 5                Fair                 High      Left
# 6                Good               Medium      Left
# 7           Excellent                  Low    Stayed
# 8                Fair               Medium    Stayed
# 9                Good                  Low      Left
#
# [10 rows x 24 columns]

# %%
df.tail(10)
# Out:
#        Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 74488        54362   30  Female                 6       Media            6353
# 74489        44995   39    Male                25     Finance           11586
# 74490        16169   47    Male                13   Education            4024
# 74491         6323   34    Male                25       Media            6717
# 74492        68796   52    Male                13  Technology            9296
# 74493        16243   56  Female                42  Healthcare            7830
# 74494        47175   30  Female                15   Education            3856
# 74495        12409   52    Male                 5   Education            5654
# 74496         9554   18    Male                 4   Education            5276
# 74497        73042   59  Female                48   Education            3774
#
#       Work-Life Balance Job Satisfaction Performance Rating  \
# 74488              Fair           Medium      Below Average
# 74489              Good             High            Average
# 74490              Fair              Low      Below Average
# 74491              Good             High               High
# 74492              Poor             High            Average
# 74493              Poor           Medium            Average
# 74494              Good           Medium            Average
# 74495              Good        Very High      Below Average
# 74496              Fair             High            Average
# 74497              Good             High      Below Average
#
#        Number of Promotions  ... Number of Dependents  Job Level Company Size  \
# 74488                   0.0  ...                  3.0     Senior        Small
# 74489                   0.0  ...                  2.0      Entry       Medium
# 74490                   2.0  ...                  6.0        Mid        Large
# 74491                   1.0  ...                  0.0        Mid        Large
# 74492                   1.0  ...                  1.0      Entry        Small
# 74493                   0.0  ...                  0.0     Senior       Medium
# 74494                   2.0  ...                  0.0      Entry       Medium
# 74495                   0.0  ...                  4.0        Mid        Small
# 74496                   0.0  ...                  3.0        Mid        Large
# 74497                   1.0  ...                  4.0        Mid        Large
#
#       Company Tenure  Remote Work Leadership Opportunities  \
# 74488             31          Yes                       No
# 74489             58           No                       No
# 74490             24          Yes                       No
# 74491             98           No                       No
# 74492             55           No                      Yes
# 74493             60           No                       No
# 74494             20           No                       No
# 74495              7           No                       No
# 74496              5           No                       No
# 74497            118           No                       No
#
#       Innovation Opportunities  Company Reputation Employee Recognition  \
# 74488                       No                Good            Very High
# 74489                       No                Good                  Low
# 74490                      Yes                Good               Medium
# 74491                       No                Good               Medium
# 74492                       No                Poor                  Low
# 74493                       No                Poor               Medium
# 74494                       No                Good               Medium
# 74495                       No                Good                 High
# 74496                       No                Poor                 High
# 74497                       No                Good            Very High
#
#       Attrition
# 74488    Stayed
# 74489      Left
# 74490    Stayed
# 74491    Stayed
# 74492    Stayed
# 74493    Stayed
# 74494      Left
# 74495      Left
# 74496    Stayed
# 74497      Left
#
# [10 rows x 24 columns]

# %%
#to print the number of rows and columns of the dataset
df.shape
# Out:
# (74498, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74498 entries, 0 to 74497
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               74498 non-null  int64
#  1   Age                       74498 non-null  int64
#  2   Gender                    74498 non-null  object
#  3   Years at Company          74498 non-null  int64
#  4   Job Role                  74498 non-null  object
#  5   Monthly Income            74498 non-null  int64
#  6   Work-Life Balance         74494 non-null  object
#  7   Job Satisfaction          74498 non-null  object
#  8   Performance Rating        74494 non-null  object
#  9   Number of Promotions      74493 non-null  float64
#  10  Overtime                  74498 non-null  object
#  11  Distance from Home        74498 non-null  int64
#  12  Education Level           74493 non-null  object
#  13  Marital Status            74494 non-null  object
#  14  Number of Dependents      74492 non-null  float64
#  15  Job Level                 74493 non-null  object
#  16  Company Size              74496 non-null  object
#  17  Company Tenure            74498 non-null  int64
#  18  Remote Work               74495 non-null  object
#  19  Leadership Opportunities  74498 non-null  object
#  20  Innovation Opportunities  74498 non-null  object
#  21  Company Reputation        74498 non-null  object
#  22  Employee Recognition      74496 non-null  object
#  23  Attrition                 74498 non-null  object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 13.6+ MB

# %%
df.describe()
# Out:
#         Employee ID           Age  Years at Company  Monthly Income  \
# count  74498.000000  74498.000000      74498.000000    74498.000000
# mean   37249.500000     38.529746         15.721603     7299.379514
# std    21505.864514     12.083456         11.223744     2152.508566
# min        1.000000     18.000000          1.000000     1226.000000
# 25%    18625.250000     28.000000          7.000000     5652.000000
# 50%    37249.500000     39.000000         13.000000     7348.000000
# 75%    55873.750000     49.000000         23.000000     8876.000000
# max    74498.000000     59.000000         51.000000    16149.000000
#
#        Number of Promotions  Distance from Home  Number of Dependents  \
# count          74493.000000        74498.000000          74492.000000
# mean               0.832978           49.991584              1.650365
# std                0.995303           28.513611              1.553660
# min                0.000000            1.000000              0.000000
# 25%                0.000000           25.000000              0.000000
# 50%                1.000000           50.000000              1.000000
# 75%                2.000000           75.000000              3.000000
# max                4.000000           99.000000              6.000000
#
#        Company Tenure
# count    74498.000000
# mean        55.727456
# std         25.399349
# min          2.000000
# 25%         36.000000
# 50%         56.000000
# 75%         76.000000
# max        128.000000

# %% [markdown]
# Checking missing values

# %%
df.isnull().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           4
# Job Satisfaction            0
# Performance Rating          4
# Number of Promotions        5
# Overtime                    0
# Distance from Home          0
# Education Level             5
# Marital Status              4
# Number of Dependents        6
# Job Level                   5
# Company Size                2
# Company Tenure              0
# Remote Work                 3
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        2
# Attrition                   0
# dtype: int64

# %%
missing_values = df.isnull().sum()
print("Missing values per column:\n", missing_values[missing_values > 0])
# Out:
# Missing values per column:
#  Work-Life Balance       4
# Performance Rating      4
# Number of Promotions    5
# Education Level         5
# Marital Status          4
# Number of Dependents    6
# Job Level               5
# Company Size            2
# Remote Work             3
# Employee Recognition    2
# dtype: int64

# %%
missing_percentage = df.isnull().mean() * 100
print("Percentage of missing values per column:\n", missing_percentage[missing_percentage > 0])
# Out:
# Percentage of missing values per column:
#  Work-Life Balance       0.005369
# Performance Rating      0.005369
# Number of Promotions    0.006712
# Education Level         0.006712
# Marital Status          0.005369
# Number of Dependents    0.008054
# Job Level               0.006712
# Company Size            0.002685
# Remote Work             0.004027
# Employee Recognition    0.002685
# dtype: float64

# %%
df['Work-Life Balance'].value_counts()
# Out:
# Work-Life Balance
# 2    28157
# 1    22528
# 0    13431
# 3    10378
# 4        4
# Name: count, dtype: int64

# %%
df['Work-Life Balance'].fillna(df['Work-Life Balance'].mode()[0], inplace=True)
df['Performance Rating'].fillna(df['Performance Rating'].mode()[0], inplace=True)
df['Number of Promotions'].fillna(df['Number of Promotions'].mean(), inplace=True)
df['Education Level'].fillna(df['Education Level'].mode()[0], inplace=True)
df['Marital Status'].fillna(df['Marital Status'].mode()[0],inplace=True)
df['Number of Dependents'].fillna(df['Number of Dependents'].mean(), inplace=True)
df['Job Level'].fillna(df['Job Level'].mode()[0], inplace=True)
df['Company Size'].fillna(df['Company Size'].mode()[0], inplace=True)
df['Remote Work'].fillna(df['Remote Work'].mode()[0],inplace=True)
df['Employee Recognition'].fillna(df['Employee Recognition'].mode()[0], inplace=True)

# %%
df.isna().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           0
# Job Satisfaction            0
# Performance Rating          0
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             0
# Marital Status              0
# Number of Dependents        0
# Job Level                   0
# Company Size                0
# Company Tenure              0
# Remote Work                 0
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        0
# Attrition                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Employee ID                   int64
# Age                           int64
# Gender                       object
# Years at Company              int64
# Job Role                     object
# Monthly Income                int64
# Work-Life Balance            object
# Job Satisfaction             object
# Performance Rating           object
# Number of Promotions        float64
# Overtime                     object
# Distance from Home            int64
# Education Level              object
# Marital Status               object
# Number of Dependents        float64
# Job Level                    object
# Company Size                 object
# Company Tenure                int64
# Remote Work                  object
# Leadership Opportunities     object
# Innovation Opportunities     object
# Company Reputation           object
# Employee Recognition         object
# Attrition                    object
# dtype: object

# %% [markdown]
# Attrition

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# Stayed    39128
# Left      35370
# Name: count, dtype: int64

# %%
#Visualize the Number of Employees that stayed and left the company
sns.countplot(df['Attrition'], palette=['yellow', 'green'])
# Out:
# <ipython-input-95-282107979307>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df['Attrition'], palette=['yellow', 'green'])
# <Axes: xlabel='count', ylabel='Attrition'>

# %%
# Bar plots for categorical variables
for col in categorical_cols:
    plt.figure(figsize=(10, 5))
    sns.countplot(x=col, data=df)
    plt.xticks(rotation=90)
    plt.show()

# %%
# 2. Correlation Analysis
# Correlation matrix
corr_matrix = data[numerical_cols].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
# 3. Attrition Analysis
# Distribution of target variable
sns.countplot(x='Attrition', data=data)
plt.show()

# %%
# 3. Attrition Analysis
# Distribution of target variable
sns.countplot(x='Attrition', data=data)
plt.show()

# Analyze features with respect to target variable
for col in numerical_cols:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x='Attrition', y=col, data=data)
    plt.show()

for col in categorical_cols:
    # Check if the column exists in the data
    if col in data.columns:
        plt.figure(figsize=(10, 5))
        sns.countplot(x=col, hue='Attrition', data=data)
        plt.xticks(rotation=90)
        plt.show()
    else:
        print(f"Column '{col}' not found in data.")
# Out:
# Column 'Job Role' not found in data.
# Column 'Work-Life Balance' not found in data.
# Column 'Job Satisfaction' not found in data.
# Column 'Performance Rating' not found in data.
# Column 'Education Level' not found in data.
# Column 'Marital Status' not found in data.
# Column 'Job Level' not found in data.
# Column 'Company Size' not found in data.
# Column 'Company Reputation' not found in data.
# Column 'Employee Recognition' not found in data.

# %%
# 4. Outlier Detection
for col in numerical_cols:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x=data[col])
    plt.show()

# %%
#Print all the columns and their Unique Values
for column in df.columns:
    if df[column].dtype == 'object':
        print(str(column)+ '  :'+ str(df[column].unique()))
        print(df[column].value_counts())
        print('------------------------------------------------------------')
# Out:
# Gender  :['Male' 'Female']
# Gender
# Male      40826
# Female    33672
# Name: count, dtype: int64
# ------------------------------------------------------------
# Job Role  :['Education' 'Media' 'Healthcare' 'Technology' 'Finance']
# Job Role
# Technology    19322
# Healthcare    17074
# Education     15658
# Media         11996
# Finance       10448
# Name: count, dtype: int64
# ------------------------------------------------------------
# Work-Life Balance  :['Excellent' 'Poor' 'Good' 'Fair']
# Work-Life Balance
# Good         28161
# Fair         22528
# Excellent    13431
# Poor         10378
# Name: count, dtype: int64
# ------------------------------------------------------------
# Job Satisfaction  :['Medium' 'High' 'Very High' 'Low']
# Job Satisfaction
# High         37245
# Very High    15079
# Medium       14717
# Low           7457
# Name: count, dtype: int64
# ------------------------------------------------------------
# Performance Rating  :['Average' 'Low' 'High' 'Below Average']
# Performance Rating
# Average          44720
# High             14910
# Below Average    11139
# Low               3729
# Name: count, dtype: int64
# ------------------------------------------------------------
# Overtime  :['No' 'Yes']
# Overtime
# No     50157
# Yes    24341
# Name: count, dtype: int64
# ------------------------------------------------------------
# Education Level  :['Associate Degree' 'Master’s Degree' 'Bachelor’s Degree' 'High School'
#  'PhD']
# Education Level
# Bachelor’s Degree    22336
# Associate Degree     18648
# Master’s Degree      15019
# High School          14679
# PhD                   3816
# Name: count, dtype: int64
# ------------------------------------------------------------
# Marital Status  :['Married' 'Divorced' 'Single']
# Marital Status
# Married     37421
# Single      25999
# Divorced    11078
# Name: count, dtype: int64
# ------------------------------------------------------------
# Job Level  :['Mid' 'Senior' 'Entry']
# Job Level
# Entry     29783
# Mid       29676
# Senior    15039
# Name: count, dtype: int64
# ------------------------------------------------------------
# Company Size  :['Medium' 'Small' 'Large']
# Company Size
# Medium    37232
# Small     22354
# Large     14912
# Name: count, dtype: int64
# ------------------------------------------------------------
# Remote Work  :['No' 'Yes']
# Remote Work
# No     60300
# Yes    14198
# Name: count, dtype: int64
# ------------------------------------------------------------
# Leadership Opportunities  :['No' 'Yes']
# Leadership Opportunities
# No     70845
# Yes     3653
# Name: count, dtype: int64
# ------------------------------------------------------------
# Innovation Opportunities  :['No' 'Yes']
# Innovation Opportunities
# No     62394
# Yes    12104
# Name: count, dtype: int64
# ------------------------------------------------------------
# Company Reputation  :['Excellent' 'Fair' 'Poor' 'Good']
# Company Reputation
# Good         37182
# Poor         15116
# Fair         14786
# Excellent     7414
# Name: count, dtype: int64
# ------------------------------------------------------------
# Employee Recognition  :['Medium' 'Low' 'High' 'Very High']
# Employee Recognition
# Low          29621
# Medium       22656
# High         18550
# Very High     3671
# Name: count, dtype: int64
# ------------------------------------------------------------
# Attrition  :['Stayed' 'Left']
# Attrition
# Stayed    39128
# Left      35370
# Name: count, dtype: int64
# ------------------------------------------------------------

# %%
#Remove Unnecessary columns
df.drop('Employee ID',axis=1,inplace=True)

# %%
df=pd.get_dummies(df)

# %%
#Transform the data
#Transform Numerical col into Non Numerical Column
from sklearn.preprocessing import LabelEncoder

for column in df.columns:
  if df[column].dtype==np.number:
    continue
    df[column]=LabelEncoder().fit_transform(df[column])
# Out:
# <ipython-input-107-e3551d96f1f7>:6: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype==np.number:

# %% [markdown]
# Age

# %%
#Create a New Column
df['Age_year']=df['Age']

# %%
df.drop('Age',axis=1,inplace=True)

# %%
#Split the data
X=df.iloc[:,1:df.shape[1]].values
Y=df.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
#Use random forest Classifier
from sklearn.ensemble import RandomForestClassifier
forest=RandomForestClassifier(n_estimators=100,random_state=42)
forest.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
#Confusion Matrix and and accuracy for the model on the test data
from sklearn.metrics import confusion_matrix,classification_report
Y_pred=forest.predict(X_test)
cm=confusion_matrix(Y_test,Y_pred)

# %%
TN=cm[0][0]
TP=cm[1][1]
FN=cm[1][0]
FP=cm[0][1]
print('Testing Accuracy=',(TP+TN)/(TP+TN+FN+FP))
# Out:
# Testing Accuracy= 0.47368421052631576
